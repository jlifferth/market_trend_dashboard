# %%
import yfinance as yf
import pandas as pd

# %%
start = '20210101'
end = '20210101'

aapl = yf.Ticker('AAPL')
aapl_price = aapl.history(period='max')

# %%
aapl_price
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 1980-12-12    0.100326    0.100762    0.100326    0.100326  469033600
# 1980-12-15    0.095528    0.095528    0.095092    0.095092  175884800
# 1980-12-16    0.088548    0.088548    0.088112    0.088112  105728000
# 1980-12-17    0.090293    0.090729    0.090293    0.090293   86441600
# 1980-12-18    0.092911    0.093347    0.092911    0.092911   73449600
# ...                ...         ...         ...         ...        ...
# 2022-03-01  164.699997  166.600006  161.970001  163.199997   83474400
# 2022-03-02  164.389999  167.360001  162.949997  166.559998   79724800
# 2022-03-03  168.470001  168.910004  165.550003  166.229996   76678400
# 2022-03-04  164.490005  165.550003  162.100006  163.169998   83737200
# 2022-03-07  163.360001  165.020004  159.039993  159.300003   96056156
#
#             Dividends  Stock Splits
# Date
# 1980-12-12        0.0           0.0
# 1980-12-15        0.0           0.0
# ...

# %%
btc = yf.Ticker('BTC-USD')
btc_price = btc.history(period='max')

# %%
btc_price
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2022-03-03  43925.195312  44021.578125  41914.750000  42451.789062
# 2022-03-04  42458.140625  42479.613281  38805.847656  39137.605469
# 2022-03-05  39148.449219  39566.335938  38777.035156  39400.585938
# 2022-03-06  39404.199219  39640.175781  38211.648438  38419.984375
# 2022-03-08  37962.652344  38838.320312  37962.652344  38573.105469
#
#                  Volume  Dividends  Stock Splits
# Date
# 2014-09-17     21056800          0             0
# 2014-09-18     34483200          0             0
# ...

# %%
btc_price = btc_price.drop(columns=['Dividends','Stock Splits'])

# %%
btc_price.iloc[1]
# Out:
# Open      4.568600e+02
# High      4.568600e+02
# Low       4.131040e+02
# Close     4.244400e+02
# Volume    3.448320e+07
# Name: 2014-09-18 00:00:00, dtype: float64

# %%
result = btc_price.to_json(orient="table", date_format="iso")
result
# Out:
# '{"schema":{"fields":[{"name":"Date","type":"datetime"},{"name":"Open","type":"number"},{"name":"High","type":"number"},{"name":"Low","type":"number"},{"name":"Close","type":"number"},{"name":"Volume","type":"integer"}],"primaryKey":["Date"],"pandas_version":"0.20.0"},"data":[{"Date":"2014-09-17T00:00:00.000Z","Open":465.8640136719,"High":468.1740112305,"Low":452.4219970703,"Close":457.3340148926,"Volume":21056800},{"Date":"2014-09-18T00:00:00.000Z","Open":456.8599853516,"High":456.8599853516,"Low":413.1040039062,"Close":424.4400024414,"Volume":34483200},{"Date":"2014-09-19T00:00:00.000Z","Open":424.1029968262,"High":427.8349914551,"Low":384.5320129395,"Close":394.7959899902,"Volume":37919700},{"Date":"2014-09-20T00:00:00.000Z","Open":394.6730041504,"High":423.2959899902,"Low":389.8829956055,"Close":408.9039916992,"Volume":36863600},{"Date":"2014-09-21T00:00:00.000Z","Open":408.0849914551,"High":412.425994873,"Low":393.1809997559,"Close":398.8210144043,"Volume":26580100},{"Date":"201
# ...

# %%
import json

# %%
parsed = json.loads(result)
json.dumps(parsed, indent=4)
# Out:
# '{\n    "schema": {\n        "fields": [\n            {\n                "name": "Date",\n                "type": "datetime"\n            },\n            {\n                "name": "Open",\n                "type": "number"\n            },\n            {\n                "name": "High",\n                "type": "number"\n            },\n            {\n                "name": "Low",\n                "type": "number"\n            },\n            {\n                "name": "Close",\n                "type": "number"\n            },\n            {\n                "name": "Volume",\n                "type": "integer"\n            }\n        ],\n        "primaryKey": [\n            "Date"\n        ],\n        "pandas_version": "0.20.0"\n    },\n    "data": [\n        {\n            "Date": "2014-09-17T00:00:00.000Z",\n            "Open": 465.8640136719,\n            "High": 468.1740112305,\n            "Low": 452.4219970703,\n            "Close": 457.3340148926,\n            "Volume": 210568
# ...

# %%
btc
# Out:
# yfinance.Ticker object <BTC-USD>

# %%
# access price data at smaller intervals

btc_hour = btc.history(period='3mo', interval='1h')
btc_hour
# Out:
#                                    Open          High           Low  \
# 2021-12-08 04:00:00+00:00  50136.054688  50450.222656  50136.054688
# 2021-12-08 05:00:00+00:00  50270.257812  50579.894531  50215.773438
# 2021-12-08 06:00:00+00:00  50482.578125  50736.578125  50480.804688
# 2021-12-08 07:00:00+00:00  50687.218750  50698.183594  50473.562500
# 2021-12-08 08:00:00+00:00  50545.738281  50631.207031  50362.945312
# ...                                 ...           ...           ...
# 2022-03-08 01:00:00+00:00  38253.636719  38445.320312  38149.222656
# 2022-03-08 02:00:00+00:00  38372.992188  38838.320312  38223.167969
# 2022-03-08 03:00:00+00:00  38667.320312  38688.750000  38573.089844
# 2022-03-08 04:00:00+00:00  38669.277344  38685.730469  38669.277344
# 2022-03-08 04:02:00+00:00  38674.253906  38674.253906  38674.253906
#
#                                   Close     Volume  Dividends  Stock Splits
# ...
